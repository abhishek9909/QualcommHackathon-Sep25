# %%
import random
import numpy as np
from typing import List, Tuple, Dict
import json
import csv
from pathlib import Path

# %%
class AlgorithmicNoiseInjector:
    def __init__(self,
                 hold_mu: float = 3.0,
                 hold_sigma: float = 1.0,
                 p_sub: float = 0.10,
                 p_del: float = 0.05,
                 max_pause_frames: int = 2,
                 frame_jitter: bool = True):
        """
        Initialize the noise injector with configurable parameters.

        Args:
            hold_mu: Mean for normal distribution of letter repetitions
            hold_sigma: Standard deviation for letter repetitions
            p_sub: Probability of letter substitution
            p_del: Probability of letter deletion
            max_pause_frames: Maximum pause frames between letters
            frame_jitter: Whether to add frame counter jitter
        """
        self.hold_mu = hold_mu
        self.hold_sigma = hold_sigma
        self.p_sub = p_sub
        self.p_del = p_del
        self.max_pause_frames = max_pause_frames
        self.frame_jitter = frame_jitter

        # Visually similar letter mappings for substitution
        self.similar_letters = {
            'A': ['A', 'H'],
            'B': ['B', 'P', 'R'],
            'C': ['C', 'O'],
            'D': ['D', 'G', 'O'],
            'E': ['E', 'F'],
            'F': ['F', 'E', 'P'],
            'G': ['G', 'D', 'O'],
            'H': ['H', 'A', 'N'],
            'I': ['I', 'J', 'L'],
            'J': ['J', 'I'],
            'K': ['K', 'H'],
            'L': ['L', 'I'],
            'M': ['M', 'N', 'W'],
            'N': ['N', 'M', 'H'],
            'O': ['O', 'C', 'D', 'G'],
            'P': ['P', 'B', 'F', 'R'],
            'Q': ['Q', 'O'],
            'R': ['R', 'B', 'P'],
            'S': ['S', 'Z'],
            'T': ['T', 'F'],
            'U': ['U', 'V'],
            'V': ['V', 'U'],
            'W': ['W', 'M'],
            'X': ['X', 'Y'],
            'Y': ['Y', 'X'],
            'Z': ['Z', 'S']
        }

    def sample_hold_duration(self) -> int:
        """Sample hold duration from normal distribution, minimum 1."""
        return max(1, round(np.random.normal(self.hold_mu, self.hold_sigma)))

    def substitute_letter(self, letter: str) -> str:
        """Substitute a letter with a visually similar one."""
        if letter.upper() in self.similar_letters:
            candidates = self.similar_letters[letter.upper()]
            # Keep original case
            substitution = random.choice(candidates)
            return substitution.lower() if letter.islower() else substitution
        return letter

    def inject_noise(self, clean_text: str) -> Tuple[str, List[Dict]]:
        """
        Inject noise into clean text following the algorithmic approach.

        Args:
            clean_text: Original clean text

        Returns:
            Tuple of (noisy_text, metadata_list)
        """
        noisy_chars = []
        metadata = []
        frame_counter = 0

        for i, char in enumerate(clean_text.upper()):
            char_metadata = {
                'original_char': char,
                'position': i,
                'operations': []
            }

            # Skip spaces and punctuation - just add them as-is
            if not char.isalpha():
                noisy_chars.append(char)
                char_metadata['final_char'] = char
                char_metadata['frame_start'] = frame_counter
                char_metadata['frame_end'] = frame_counter
                frame_counter += 1
                metadata.append(char_metadata)
                continue

            # Step 1: Sample hold duration
            hold = self.sample_hold_duration()
            char_metadata['hold_duration'] = hold
            char_metadata['operations'].append(f'hold_{hold}')

            # Step 2: Deletion check
            if random.random() < self.p_del:
                char_metadata['operations'].append('deleted')
                char_metadata['final_char'] = ''
                char_metadata['frame_start'] = frame_counter
                char_metadata['frame_end'] = frame_counter
                metadata.append(char_metadata)
                continue

            # Step 3: Substitution check
            final_char = char
            if random.random() < self.p_sub:
                final_char = self.substitute_letter(char)
                char_metadata['operations'].append(f'substituted_to_{final_char}')

            # Step 4: Apply hold (repeat the character)
            char_metadata['frame_start'] = frame_counter
            for _ in range(hold):
                noisy_chars.append(final_char)
                if self.frame_jitter and random.random() < 0.1:  # 10% chance of jitter
                    jitter = random.choice([-1, 1])
                    frame_counter += jitter
                    char_metadata['operations'].append(f'jitter_{jitter}')
                frame_counter += 1
            char_metadata['frame_end'] = frame_counter - 1
            char_metadata['final_char'] = final_char

            # Step 5: Insert random pause (no-sign tokens)
            if i < len(clean_text) - 1:  # Don't add pause after last character
                pause_length = random.randint(0, self.max_pause_frames)
                if pause_length > 0:
                    for _ in range(pause_length):
                        noisy_chars.append('[NO_SIGN]')
                        frame_counter += 1
                    char_metadata['operations'].append(f'pause_{pause_length}')

            metadata.append(char_metadata)

        return ''.join(noisy_chars), metadata

    def create_dataset(self,
                      clean_texts: List[str],
                      output_path: str = "noisy_dataset.json") -> Dict:
        """
        Create a complete dataset with noise injection applied to all texts.

        Args:
            clean_texts: List of clean text strings
            output_path: Path to save the dataset

        Returns:
            Dictionary containing the complete dataset
        """
        dataset = {
            'config': {
                'hold_mu': self.hold_mu,
                'hold_sigma': self.hold_sigma,
                'p_sub': self.p_sub,
                'p_del': self.p_del,
                'max_pause_frames': self.max_pause_frames,
                'frame_jitter': self.frame_jitter
            },
            'data': []
        }

        for i, clean_text in enumerate(clean_texts):
            noisy_text, metadata = self.inject_noise(clean_text)

            dataset['data'].append({
                'id': i,
                'clean_text': clean_text,
                'noisy_text': noisy_text,
                'metadata': metadata,
                'stats': {
                    'original_length': len(clean_text),
                    'noisy_length': len(noisy_text),
                    'expansion_ratio': len(noisy_text) / len(clean_text) if len(clean_text) > 0 else 0,
                    'operations_count': sum(len(m['operations']) for m in metadata)
                }
            })

        # Save to file
        with open(output_path, 'w') as f:
            json.dump(dataset, f, indent=2)

        return dataset

# %%
import random

def load_common_english_dataset():
    """
    Returns a list of common English sentences, each ~3-5 words.

    Args:
        sample_size (int): Number of sentences to return.

    Returns:
        List[str]: List of sentences.
    """
    # Example pool of common English sentences
    sentences = [
        "How are you today",
        "I love reading books",
        "Can you help me",
        "This is my friend",
        "What is your name",
        "I need some water",
        "Where is the station",
        "She is very kind",
        "I am feeling happy",
        "He likes to run",
        "Do you know this",
        "It is a sunny day",
        "Please give me that",
        "I am going home",
        "We are learning Python",
        "They are very nice",
        "Can I ask something",
        "This is very easy",
        "I want some coffee",
        "What time is it",
        "I am reading now",
        "He is my brother",
        "She is my sister",
        "We are best friends",
        "It is very cold",
        "I like this song",
        "Do you like it",
        "Please sit over there",
        "I will call you",
        "That is my book"
    ]

    return random.sample(sentences, min(sample_size, len(sentences)))

# %%
def demonstrate_noise_injection():
    """Demonstrate the noise injection system."""
    print("=== ASL-Based Algorithmic Noise Injection Demo ===\n")

    # Initialize the noise injector
    injector = AlgorithmicNoiseInjector(
        hold_mu=3.0,
        hold_sigma=1.0,
        p_sub=0.10,
        p_del=0.05,
        max_pause_frames=2,
        frame_jitter=True
    )

    # Load some sample texts.
    print("Loading some English sample sentences. (not from any dataset, this is just simple stuff for now.)")
    sample_texts = load_common_english_dataset()

    # Demonstrate on a few examples
    print(f"\nLoaded {len(sample_texts)} sentences. Here are some examples:")
    print("=" * 60)
    for i, text in enumerate(sample_texts[:5]):
        noisy, metadata = injector.inject_noise(text)
        print(f"Example {i+1}:")
        print(f"Clean:  {text}")
        print(f"Noisy:  {noisy}")
        print(f"Ops:    {sum(len(m['operations']) for m in metadata)} operations applied")
        print("-" * 60)

    # Create full dataset
    print(f"Creating full dataset with {len(sample_texts)} samples...")
    dataset = injector.create_dataset(sample_texts, "asl_noisy_dataset.json")

    # Print statistics
    total_samples = len(dataset['data'])
    avg_expansion = np.mean([d['stats']['expansion_ratio'] for d in dataset['data']])
    total_ops = sum([d['stats']['operations_count'] for d in dataset['data']])

    print(f"\nDataset Statistics:")
    print(f"- Total samples: {total_samples}")
    print(f"- Average expansion ratio: {avg_expansion:.2f}x")
    print(f"- Total operations applied: {total_ops}")
    print(f"- Dataset saved to: asl_noisy_dataset.json")

    # Show some ASL substitution examples
    print(f"\nASL Hand Shape Substitutions Used:")
    print("(Common confusions in ASL fingerspelling)")
    print("- D ↔ F (commonly confused)")
    print("- M ↔ N (very similar hand shapes)")
    print("- A ↔ S ↔ T (all closed fist variations)")
    print("- K ↔ P (thumb on middle finger)")
    print("- H ↔ U (similar orientations)")
    print("- B ↔ U ↔ V (extended fingers)")

    return dataset

# %%
random.seed(42)
np.random.seed(42)
demonstrate_noise_injection()
# Out:
# === ASL-Based Algorithmic Noise Injection Demo ===
#
# Loading some English sample sentences. (not from any dataset, this is just simple stuff for now.)
#
# Loaded 30 sentences. Here are some examples:
# ============================================================
# Example 1:
# Clean:  I am reading now
# Noisy:  III[NO_SIGN] AAAMMMM[NO_SIGN][NO_SIGN] RRRRREEE[NO_SIGN][NO_SIGN]AAA[NO_SIGN][NO_SIGN]DDDDDJJJJ[NO_SIGN][NO_SIGN]NNN[NO_SIGN][NO_SIGN]GGGG NNN[NO_SIGN]OOOWWW
# Ops:    24 operations applied
# ------------------------------------------------------------
# Example 2:
# Clean:  This is my friend
# Noisy:  TH[NO_SIGN][NO_SIGN]II[NO_SIGN][NO_SIGN]SS[NO_SIGN][NO_SIGN] III[NO_SIGN]SS MM[NO_SIGN][NO_SIGN]YYYY[NO_SIGN][NO_SIGN] FFF[NO_SIGN][NO_SIGN]RRREENNN[NO_SIGN][NO_SIGN]DD
# Ops:    26 operations applied
# ------------------------------------------------------------
# Example 3:
# Clean:  How are you today
# Noisy:  HHHOOWWW AARRRRR[NO_SIGN]EEE[NO_SIGN] YY[NO_SIGN][NO_SIGN]OOOO[NO_SIGN][NO_SIGN]UU TTT[NO_SIGN]O[NO_SIGN]DD[NO_SIGN][NO_SIGN]AAAYYYY
# Ops:    30 operations applied
# ------------------------------------------------------------
# Example 4:
# Clean:  We are best friends
# Noisy:  WWW[NO_SIGN][NO_SIGN]EEE AAARR[NO_SIGN]EE EEEESSS[NO_SIGN][NO_SIGN]T FFF[NO_SIGN]RRRLL[NO_SIGN]EEEENNNNDDDD[NO_SIGN][NO_SIGN]SS
# Ops:    28 operations applied
# ------------------------------------------------------------
# Example 5:
# Clean:  I am feeling happy
# Noisy:  III AAAMMMM FFF[NO_SIGN]EEEEE[NO_SIGN][NO_SIGN]LLIIII[NO_SIGN]NNNN[NO_SIGN][NO_SIGN]GGG AAAA[NO_SIGN][NO_SIGN]AAAPPPPPYYYYY
# Ops:    23 operations applied
# ------------------------------------------------------------
# Creating full dataset with 30 samples...
#
# Dataset Statistics:
# - Total samples: 30
# - Average expansion ratio: 9.11x
# - Total operations applied: 845
# - Dataset saved to: asl_noisy_dataset.json
#
# ASL Hand Shape Substitutions Used:
# (Common confusions in ASL fingerspelling)
# - D ↔ F (commonly confused)
# - M ↔ N (very similar hand shapes)
# - A ↔ S ↔ T (all closed fist variations)
# - K ↔ P (thumb on middle finger)
# - H ↔ U (similar orientations)
# - B ↔ U ↔ V (extended fingers)
# {'config': {'hold_mu': 3.0,
#   'hold_sigma': 1.0,
#   'p_sub': 0.1,
#   'p_del': 0.05,
#   'max_pause_frames': 2,
#   'frame_jitter': True},
#  'data': [{'id': 0,
#    'clean_text': 'I am reading now',
#    'noisy_text': 'III AAAAA[NO_SIGN][NO_SIGN]M RRRR[NO_SIGN][NO_SIGN]EEE[NO_SIGN]AAA[NO_SIGN]DDD[NO_SIGN]INNN[NO_SIGN]GGG[NO_SIGN] NNNN[NO_SIGN]OO[NO_SIGN]WW',
#    'metadata': [{'original_char': 'I',
#      'position': 0,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 0,
#      'frame_end': 2,
#      'final_char': 'I'},
#     {'original_char': ' ',
#      'position': 1,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 3,
#      'frame_end': 3},
#     {'original_char': 'A',
#      'position': 2,
#      'operations': ['hold_5', 'pause_2'],
#      'hold_duration': 5,
#      'frame_start': 4,
#      'frame_end': 8,
#      'final_char': 'A'},
#     {'original_char': 'M',
#      'position': 3,
#      'operations': ['hold_1'],
#      'hold_duration': 1,
#      'frame_start': 11,
#      'frame_end': 11,
#      'final_char': 'M'},
#     {'original_char': ' ',
#      'position': 4,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 12,
#      'frame_end': 12},
#     {'original_char': 'R',
#      'position': 5,
#      'operations': ['hold_4', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 13,
#      'frame_end': 16,
#      'final_char': 'R'},
#     {'original_char': 'E',
#      'position': 6,
#      'operations': ['hold_3', 'jitter_1', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 19,
#      'frame_end': 22,
#      'final_char': 'E'},
#     {'original_char': 'A',
#      'position': 7,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 24,
#      'frame_end': 26,
#      'final_char': 'A'},
#     {'original_char': 'D',
#      'position': 8,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 28,
#      'frame_end': 30,
#      'final_char': 'D'},
#     {'original_char': 'I',
#      'position': 9,
#      'operations': ['hold_1'],
#      'hold_duration': 1,
#      'frame_start': 32,
#      'frame_end': 32,
#      'final_char': 'I'},
#     {'original_char': 'N',
#      'position': 10,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 33,
#      'frame_end': 35,
#      'final_char': 'N'},
#     {'original_char': 'G',
#      'position': 11,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 37,
#      'frame_end': 39,
#      'final_char': 'G'},
#     {'original_char': ' ',
#      'position': 12,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 41,
#      'frame_end': 41},
#     {'original_char': 'N',
#      'position': 13,
#      'operations': ['hold_4', 'jitter_1', 'jitter_1', 'pause_1'],
#      'hold_duration': 4,
#      'frame_start': 42,
#      'frame_end': 47,
#      'final_char': 'N'},
#     {'original_char': 'O',
#      'position': 14,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 49,
#      'frame_end': 50,
#      'final_char': 'O'},
#     {'original_char': 'W',
#      'position': 15,
#      'operations': ['hold_2', 'substituted_to_W', 'jitter_1'],
#      'hold_duration': 2,
#      'frame_start': 52,
#      'frame_end': 54,
#      'final_char': 'W'}],
#    'stats': {'original_length': 16,
#     'noisy_length': 139,
#     'expansion_ratio': 8.6875,
#     'operations_count': 27}},
#   {'id': 1,
#    'clean_text': 'This is my friend',
#    'noisy_text': 'TTHHHH[NO_SIGN]IIISS[NO_SIGN] IIII[NO_SIGN][NO_SIGN]SSS[NO_SIGN][NO_SIGN] MMMM[NO_SIGN]YY[NO_SIGN] FFF[NO_SIGN][NO_SIGN]RRRJJ[NO_SIGN][NO_SIGN]EEE[NO_SIGN]NNNDDD',
#    'metadata': [{'original_char': 'T',
#      'position': 0,
#      'operations': ['hold_2', 'substituted_to_T'],
#      'hold_duration': 2,
#      'frame_start': 0,
#      'frame_end': 1,
#      'final_char': 'T'},
#     {'original_char': 'H',
#      'position': 1,
#      'operations': ['hold_4', 'pause_1'],
#      'hold_duration': 4,
#      'frame_start': 2,
#      'frame_end': 5,
#      'final_char': 'H'},
#     {'original_char': 'I',
#      'position': 2,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 7,
#      'frame_end': 9,
#      'final_char': 'I'},
#     {'original_char': 'S',
#      'position': 3,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 10,
#      'frame_end': 11,
#      'final_char': 'S'},
#     {'original_char': ' ',
#      'position': 4,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 13,
#      'frame_end': 13},
#     {'original_char': 'I',
#      'position': 5,
#      'operations': ['hold_4', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 14,
#      'frame_end': 17,
#      'final_char': 'I'},
#     {'original_char': 'S',
#      'position': 6,
#      'operations': ['hold_3', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 20,
#      'frame_end': 22,
#      'final_char': 'S'},
#     {'original_char': ' ',
#      'position': 7,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 25,
#      'frame_end': 25},
#     {'original_char': 'M',
#      'position': 8,
#      'operations': ['hold_4', 'pause_1'],
#      'hold_duration': 4,
#      'frame_start': 26,
#      'frame_end': 29,
#      'final_char': 'M'},
#     {'original_char': 'Y',
#      'position': 9,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 31,
#      'frame_end': 32,
#      'final_char': 'Y'},
#     {'original_char': ' ',
#      'position': 10,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 34,
#      'frame_end': 34},
#     {'original_char': 'F',
#      'position': 11,
#      'operations': ['hold_3', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 35,
#      'frame_end': 37,
#      'final_char': 'F'},
#     {'original_char': 'R',
#      'position': 12,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 40,
#      'frame_end': 42,
#      'final_char': 'R'},
#     {'original_char': 'I',
#      'position': 13,
#      'operations': ['hold_2', 'substituted_to_J', 'pause_2'],
#      'hold_duration': 2,
#      'frame_start': 43,
#      'frame_end': 44,
#      'final_char': 'J'},
#     {'original_char': 'E',
#      'position': 14,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 47,
#      'frame_end': 49,
#      'final_char': 'E'},
#     {'original_char': 'N',
#      'position': 15,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 51,
#      'frame_end': 53,
#      'final_char': 'N'},
#     {'original_char': 'D',
#      'position': 16,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 54,
#      'frame_end': 56,
#      'final_char': 'D'}],
#    'stats': {'original_length': 17,
#     'noisy_length': 161,
#     'expansion_ratio': 9.470588235294118,
#     'operations_count': 25}},
#   {'id': 2,
#    'clean_text': 'How are you today',
#    'noisy_text': 'HHHOO[NO_SIGN][NO_SIGN]WWW[NO_SIGN] AAA[NO_SIGN][NO_SIGN]RR[NO_SIGN][NO_SIGN]EEE[NO_SIGN] OOOOO[NO_SIGN]VVV TTTOOO[NO_SIGN]D[NO_SIGN][NO_SIGN]AAA[NO_SIGN][NO_SIGN]YYY',
#    'metadata': [{'original_char': 'H',
#      'position': 0,
#      'operations': ['hold_3', 'jitter_1'],
#      'hold_duration': 3,
#      'frame_start': 0,
#      'frame_end': 3,
#      'final_char': 'H'},
#     {'original_char': 'O',
#      'position': 1,
#      'operations': ['hold_2', 'pause_2'],
#      'hold_duration': 2,
#      'frame_start': 4,
#      'frame_end': 5,
#      'final_char': 'O'},
#     {'original_char': 'W',
#      'position': 2,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 8,
#      'frame_end': 10,
#      'final_char': 'W'},
#     {'original_char': ' ',
#      'position': 3,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 12,
#      'frame_end': 12},
#     {'original_char': 'A',
#      'position': 4,
#      'operations': ['hold_3', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 13,
#      'frame_end': 15,
#      'final_char': 'A'},
#     {'original_char': 'R',
#      'position': 5,
#      'operations': ['hold_2', 'pause_2'],
#      'hold_duration': 2,
#      'frame_start': 18,
#      'frame_end': 19,
#      'final_char': 'R'},
#     {'original_char': 'E',
#      'position': 6,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 22,
#      'frame_end': 24,
#      'final_char': 'E'},
#     {'original_char': ' ',
#      'position': 7,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 26,
#      'frame_end': 26},
#     {'original_char': 'Y',
#      'position': 8,
#      'operations': ['hold_3', 'deleted'],
#      'hold_duration': 3,
#      'final_char': '',
#      'frame_start': 27,
#      'frame_end': 27},
#     {'original_char': 'O',
#      'position': 9,
#      'operations': ['hold_5', 'pause_1'],
#      'hold_duration': 5,
#      'frame_start': 27,
#      'frame_end': 31,
#      'final_char': 'O'},
#     {'original_char': 'U',
#      'position': 10,
#      'operations': ['hold_3', 'substituted_to_V'],
#      'hold_duration': 3,
#      'frame_start': 33,
#      'frame_end': 35,
#      'final_char': 'V'},
#     {'original_char': ' ',
#      'position': 11,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 36,
#      'frame_end': 36},
#     {'original_char': 'T',
#      'position': 12,
#      'operations': ['hold_3', 'jitter_1', 'jitter_-1'],
#      'hold_duration': 3,
#      'frame_start': 37,
#      'frame_end': 39,
#      'final_char': 'T'},
#     {'original_char': 'O',
#      'position': 13,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 40,
#      'frame_end': 42,
#      'final_char': 'O'},
#     {'original_char': 'D',
#      'position': 14,
#      'operations': ['hold_1', 'pause_2'],
#      'hold_duration': 1,
#      'frame_start': 44,
#      'frame_end': 44,
#      'final_char': 'D'},
#     {'original_char': 'A',
#      'position': 15,
#      'operations': ['hold_3', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 47,
#      'frame_end': 49,
#      'final_char': 'A'},
#     {'original_char': 'Y',
#      'position': 16,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 52,
#      'frame_end': 54,
#      'final_char': 'Y'}],
#    'stats': {'original_length': 17,
#     'noisy_length': 166,
#     'expansion_ratio': 9.764705882352942,
#     'operations_count': 28}},
#   {'id': 3,
#    'clean_text': 'We are best friends',
#    'noisy_text': 'WWWWW[NO_SIGN]EEE[NO_SIGN][NO_SIGN] AAARRREE[NO_SIGN] BBBB[NO_SIGN]FFFF[NO_SIGN][NO_SIGN]ZZZZ[NO_SIGN]TT[NO_SIGN] FFFF[NO_SIGN]RR[NO_SIGN][NO_SIGN]EEEEE[NO_SIGN]NN[NO_SIGN]DD[NO_SIGN]SSS',
#    'metadata': [{'original_char': 'W',
#      'position': 0,
#      'operations': ['hold_5', 'jitter_-1', 'pause_1'],
#      'hold_duration': 5,
#      'frame_start': 0,
#      'frame_end': 3,
#      'final_char': 'W'},
#     {'original_char': 'E',
#      'position': 1,
#      'operations': ['hold_3', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 5,
#      'frame_end': 7,
#      'final_char': 'E'},
#     {'original_char': ' ',
#      'position': 2,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 10,
#      'frame_end': 10},
#     {'original_char': 'A',
#      'position': 3,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 11,
#      'frame_end': 13,
#      'final_char': 'A'},
#     {'original_char': 'R',
#      'position': 4,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 14,
#      'frame_end': 16,
#      'final_char': 'R'},
#     {'original_char': 'E',
#      'position': 5,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 17,
#      'frame_end': 18,
#      'final_char': 'E'},
#     {'original_char': ' ',
#      'position': 6,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 20,
#      'frame_end': 20},
#     {'original_char': 'B',
#      'position': 7,
#      'operations': ['hold_4', 'pause_1'],
#      'hold_duration': 4,
#      'frame_start': 21,
#      'frame_end': 24,
#      'final_char': 'B'},
#     {'original_char': 'E',
#      'position': 8,
#      'operations': ['hold_4', 'substituted_to_F', 'jitter_-1', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 26,
#      'frame_end': 28,
#      'final_char': 'F'},
#     {'original_char': 'S',
#      'position': 9,
#      'operations': ['hold_4', 'substituted_to_Z', 'pause_1'],
#      'hold_duration': 4,
#      'frame_start': 31,
#      'frame_end': 34,
#      'final_char': 'Z'},
#     {'original_char': 'T',
#      'position': 10,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 36,
#      'frame_end': 37,
#      'final_char': 'T'},
#     {'original_char': ' ',
#      'position': 11,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 39,
#      'frame_end': 39},
#     {'original_char': 'F',
#      'position': 12,
#      'operations': ['hold_4', 'pause_1'],
#      'hold_duration': 4,
#      'frame_start': 40,
#      'frame_end': 43,
#      'final_char': 'F'},
#     {'original_char': 'R',
#      'position': 13,
#      'operations': ['hold_2', 'pause_2'],
#      'hold_duration': 2,
#      'frame_start': 45,
#      'frame_end': 46,
#      'final_char': 'R'},
#     {'original_char': 'I',
#      'position': 14,
#      'operations': ['hold_4', 'deleted'],
#      'hold_duration': 4,
#      'final_char': '',
#      'frame_start': 49,
#      'frame_end': 49},
#     {'original_char': 'E',
#      'position': 15,
#      'operations': ['hold_5', 'jitter_1', 'pause_1'],
#      'hold_duration': 5,
#      'frame_start': 49,
#      'frame_end': 54,
#      'final_char': 'E'},
#     {'original_char': 'N',
#      'position': 16,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 56,
#      'frame_end': 57,
#      'final_char': 'N'},
#     {'original_char': 'D',
#      'position': 17,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 59,
#      'frame_end': 60,
#      'final_char': 'D'},
#     {'original_char': 'S',
#      'position': 18,
#      'operations': ['hold_3', 'jitter_-1'],
#      'hold_duration': 3,
#      'frame_start': 62,
#      'frame_end': 63,
#      'final_char': 'S'}],
#    'stats': {'original_length': 19,
#     'noisy_length': 186,
#     'expansion_ratio': 9.789473684210526,
#     'operations_count': 35}},
#   {'id': 4,
#    'clean_text': 'I am feeling happy',
#    'noisy_text': ' AMMM[NO_SIGN][NO_SIGN] FF[NO_SIGN]EEEEE[NO_SIGN][NO_SIGN]IIIII[NO_SIGN]II[NO_SIGN]NNN[NO_SIGN] HH[NO_SIGN][NO_SIGN]AAA[NO_SIGN][NO_SIGN]PPPP[NO_SIGN][NO_SIGN]F[NO_SIGN][NO_SIGN]XXX',
#    'metadata': [{'original_char': 'I',
#      'position': 0,
#      'operations': ['hold_2', 'deleted'],
#      'hold_duration': 2,
#      'final_char': '',
#      'frame_start': 0,
#      'frame_end': 0},
#     {'original_char': ' ',
#      'position': 1,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 0,
#      'frame_end': 0},
#     {'original_char': 'A',
#      'position': 2,
#      'operations': ['hold_1'],
#      'hold_duration': 1,
#      'frame_start': 1,
#      'frame_end': 1,
#      'final_char': 'A'},
#     {'original_char': 'M',
#      'position': 3,
#      'operations': ['hold_3', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 2,
#      'frame_end': 4,
#      'final_char': 'M'},
#     {'original_char': ' ',
#      'position': 4,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 7,
#      'frame_end': 7},
#     {'original_char': 'F',
#      'position': 5,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 8,
#      'frame_end': 9,
#      'final_char': 'F'},
#     {'original_char': 'E',
#      'position': 6,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 11,
#      'frame_end': 13,
#      'final_char': 'E'},
#     {'original_char': 'E',
#      'position': 7,
#      'operations': ['hold_2', 'pause_2'],
#      'hold_duration': 2,
#      'frame_start': 14,
#      'frame_end': 15,
#      'final_char': 'E'},
#     {'original_char': 'L',
#      'position': 8,
#      'operations': ['hold_5', 'substituted_to_I', 'pause_1'],
#      'hold_duration': 5,
#      'frame_start': 18,
#      'frame_end': 22,
#      'final_char': 'I'},
#     {'original_char': 'I',
#      'position': 9,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 24,
#      'frame_end': 25,
#      'final_char': 'I'},
#     {'original_char': 'N',
#      'position': 10,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 27,
#      'frame_end': 29,
#      'final_char': 'N'},
#     {'original_char': 'G',
#      'position': 11,
#      'operations': ['hold_4', 'deleted'],
#      'hold_duration': 4,
#      'final_char': '',
#      'frame_start': 31,
#      'frame_end': 31},
#     {'original_char': ' ',
#      'position': 12,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 31,
#      'frame_end': 31},
#     {'original_char': 'H',
#      'position': 13,
#      'operations': ['hold_2', 'pause_2'],
#      'hold_duration': 2,
#      'frame_start': 32,
#      'frame_end': 33,
#      'final_char': 'H'},
#     {'original_char': 'A',
#      'position': 14,
#      'operations': ['hold_3', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 36,
#      'frame_end': 38,
#      'final_char': 'A'},
#     {'original_char': 'P',
#      'position': 15,
#      'operations': ['hold_4', 'jitter_1', 'jitter_-1', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 41,
#      'frame_end': 44,
#      'final_char': 'P'},
#     {'original_char': 'P',
#      'position': 16,
#      'operations': ['hold_1', 'substituted_to_F', 'pause_2'],
#      'hold_duration': 1,
#      'frame_start': 47,
#      'frame_end': 47,
#      'final_char': 'F'},
#     {'original_char': 'Y',
#      'position': 17,
#      'operations': ['hold_3', 'substituted_to_X'],
#      'hold_duration': 3,
#      'frame_start': 50,
#      'frame_end': 52,
#      'final_char': 'X'}],
#    'stats': {'original_length': 18,
#     'noisy_length': 181,
#     'expansion_ratio': 10.055555555555555,
#     'operations_count': 32}},
#   {'id': 5,
#    'clean_text': 'She is very kind',
#    'noisy_text': 'SSSHHHH[NO_SIGN]EE[NO_SIGN] II[NO_SIGN][NO_SIGN]SSSS VVV[NO_SIGN]EEE[NO_SIGN][NO_SIGN]RRR[NO_SIGN]YY[NO_SIGN] KKK[NO_SIGN][NO_SIGN]III[NO_SIGN]NNDDDDD',
#    'metadata': [{'original_char': 'S',
#      'position': 0,
#      'operations': ['hold_3', 'jitter_-1'],
#      'hold_duration': 3,
#      'frame_start': 0,
#      'frame_end': 1,
#      'final_char': 'S'},
#     {'original_char': 'H',
#      'position': 1,
#      'operations': ['hold_4', 'jitter_-1', 'pause_1'],
#      'hold_duration': 4,
#      'frame_start': 2,
#      'frame_end': 4,
#      'final_char': 'H'},
#     {'original_char': 'E',
#      'position': 2,
#      'operations': ['hold_2', 'jitter_1', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 6,
#      'frame_end': 8,
#      'final_char': 'E'},
#     {'original_char': ' ',
#      'position': 3,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 10,
#      'frame_end': 10},
#     {'original_char': 'I',
#      'position': 4,
#      'operations': ['hold_2', 'pause_2'],
#      'hold_duration': 2,
#      'frame_start': 11,
#      'frame_end': 12,
#      'final_char': 'I'},
#     {'original_char': 'S',
#      'position': 5,
#      'operations': ['hold_4', 'jitter_1'],
#      'hold_duration': 4,
#      'frame_start': 15,
#      'frame_end': 19,
#      'final_char': 'S'},
#     {'original_char': ' ',
#      'position': 6,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 20,
#      'frame_end': 20},
#     {'original_char': 'V',
#      'position': 7,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 21,
#      'frame_end': 23,
#      'final_char': 'V'},
#     {'original_char': 'E',
#      'position': 8,
#      'operations': ['hold_3', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 25,
#      'frame_end': 27,
#      'final_char': 'E'},
#     {'original_char': 'R',
#      'position': 9,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 30,
#      'frame_end': 32,
#      'final_char': 'R'},
#     {'original_char': 'Y',
#      'position': 10,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 34,
#      'frame_end': 35,
#      'final_char': 'Y'},
#     {'original_char': ' ',
#      'position': 11,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 37,
#      'frame_end': 37},
#     {'original_char': 'K',
#      'position': 12,
#      'operations': ['hold_3', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 38,
#      'frame_end': 40,
#      'final_char': 'K'},
#     {'original_char': 'I',
#      'position': 13,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 43,
#      'frame_end': 45,
#      'final_char': 'I'},
#     {'original_char': 'N',
#      'position': 14,
#      'operations': ['hold_2'],
#      'hold_duration': 2,
#      'frame_start': 47,
#      'frame_end': 48,
#      'final_char': 'N'},
#     {'original_char': 'D',
#      'position': 15,
#      'operations': ['hold_5'],
#      'hold_duration': 5,
#      'frame_start': 49,
#      'frame_end': 53,
#      'final_char': 'D'}],
#    'stats': {'original_length': 16,
#     'noisy_length': 150,
#     'expansion_ratio': 9.375,
#     'operations_count': 26}},
#   {'id': 6,
#    'clean_text': 'It is very cold',
#    'noisy_text': 'IIITT[NO_SIGN][NO_SIGN] IIII[NO_SIGN]SS[NO_SIGN] VVVV[NO_SIGN][NO_SIGN]EEEE[NO_SIGN][NO_SIGN]RR[NO_SIGN] CCC[NO_SIGN][NO_SIGN]OOOOLLLLL[NO_SIGN][NO_SIGN]DDD',
#    'metadata': [{'original_char': 'I',
#      'position': 0,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 0,
#      'frame_end': 2,
#      'final_char': 'I'},
#     {'original_char': 'T',
#      'position': 1,
#      'operations': ['hold_2', 'pause_2'],
#      'hold_duration': 2,
#      'frame_start': 3,
#      'frame_end': 4,
#      'final_char': 'T'},
#     {'original_char': ' ',
#      'position': 2,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 7,
#      'frame_end': 7},
#     {'original_char': 'I',
#      'position': 3,
#      'operations': ['hold_4', 'pause_1'],
#      'hold_duration': 4,
#      'frame_start': 8,
#      'frame_end': 11,
#      'final_char': 'I'},
#     {'original_char': 'S',
#      'position': 4,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 13,
#      'frame_end': 14,
#      'final_char': 'S'},
#     {'original_char': ' ',
#      'position': 5,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 16,
#      'frame_end': 16},
#     {'original_char': 'V',
#      'position': 6,
#      'operations': ['hold_4', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 17,
#      'frame_end': 20,
#      'final_char': 'V'},
#     {'original_char': 'E',
#      'position': 7,
#      'operations': ['hold_4', 'jitter_-1', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 23,
#      'frame_end': 25,
#      'final_char': 'E'},
#     {'original_char': 'R',
#      'position': 8,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 28,
#      'frame_end': 29,
#      'final_char': 'R'},
#     {'original_char': 'Y',
#      'position': 9,
#      'operations': ['hold_4', 'deleted'],
#      'hold_duration': 4,
#      'final_char': '',
#      'frame_start': 31,
#      'frame_end': 31},
#     {'original_char': ' ',
#      'position': 10,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 31,
#      'frame_end': 31},
#     {'original_char': 'C',
#      'position': 11,
#      'operations': ['hold_3', 'jitter_1', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 32,
#      'frame_end': 35,
#      'final_char': 'C'},
#     {'original_char': 'O',
#      'position': 12,
#      'operations': ['hold_4'],
#      'hold_duration': 4,
#      'frame_start': 38,
#      'frame_end': 41,
#      'final_char': 'O'},
#     {'original_char': 'L',
#      'position': 13,
#      'operations': ['hold_5', 'pause_2'],
#      'hold_duration': 5,
#      'frame_start': 42,
#      'frame_end': 46,
#      'final_char': 'L'},
#     {'original_char': 'D',
#      'position': 14,
#      'operations': ['hold_3', 'jitter_1'],
#      'hold_duration': 3,
#      'frame_start': 49,
#      'frame_end': 52,
#      'final_char': 'D'}],
#    'stats': {'original_length': 15,
#     'noisy_length': 156,
#     'expansion_ratio': 10.4,
#     'operations_count': 24}},
#   {'id': 7,
#    'clean_text': 'What is your name',
#    'noisy_text': 'WW[NO_SIGN]HH[NO_SIGN][NO_SIGN]AA[NO_SIGN]TTT III[NO_SIGN][NO_SIGN]SSS YYYYOOOUUUURRR[NO_SIGN][NO_SIGN] NNNNNN[NO_SIGN]AAAA[NO_SIGN]MMEE',
#    'metadata': [{'original_char': 'W',
#      'position': 0,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 0,
#      'frame_end': 1,
#      'final_char': 'W'},
#     {'original_char': 'H',
#      'position': 1,
#      'operations': ['hold_2', 'jitter_1', 'pause_2'],
#      'hold_duration': 2,
#      'frame_start': 3,
#      'frame_end': 5,
#      'final_char': 'H'},
#     {'original_char': 'A',
#      'position': 2,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 8,
#      'frame_end': 9,
#      'final_char': 'A'},
#     {'original_char': 'T',
#      'position': 3,
#      'operations': ['hold_3', 'jitter_1'],
#      'hold_duration': 3,
#      'frame_start': 11,
#      'frame_end': 14,
#      'final_char': 'T'},
#     {'original_char': ' ',
#      'position': 4,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 15,
#      'frame_end': 15},
#     {'original_char': 'I',
#      'position': 5,
#      'operations': ['hold_3', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 16,
#      'frame_end': 18,
#      'final_char': 'I'},
#     {'original_char': 'S',
#      'position': 6,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 21,
#      'frame_end': 23,
#      'final_char': 'S'},
#     {'original_char': ' ',
#      'position': 7,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 24,
#      'frame_end': 24},
#     {'original_char': 'Y',
#      'position': 8,
#      'operations': ['hold_4'],
#      'hold_duration': 4,
#      'frame_start': 25,
#      'frame_end': 28,
#      'final_char': 'Y'},
#     {'original_char': 'O',
#      'position': 9,
#      'operations': ['hold_3', 'jitter_1'],
#      'hold_duration': 3,
#      'frame_start': 29,
#      'frame_end': 32,
#      'final_char': 'O'},
#     {'original_char': 'U',
#      'position': 10,
#      'operations': ['hold_4', 'jitter_1'],
#      'hold_duration': 4,
#      'frame_start': 33,
#      'frame_end': 37,
#      'final_char': 'U'},
#     {'original_char': 'R',
#      'position': 11,
#      'operations': ['hold_3', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 38,
#      'frame_end': 40,
#      'final_char': 'R'},
#     {'original_char': ' ',
#      'position': 12,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 43,
#      'frame_end': 43},
#     {'original_char': 'N',
#      'position': 13,
#      'operations': ['hold_6', 'jitter_1', 'pause_1'],
#      'hold_duration': 6,
#      'frame_start': 44,
#      'frame_end': 50,
#      'final_char': 'N'},
#     {'original_char': 'A',
#      'position': 14,
#      'operations': ['hold_4', 'substituted_to_A', 'jitter_1', 'pause_1'],
#      'hold_duration': 4,
#      'frame_start': 52,
#      'frame_end': 56,
#      'final_char': 'A'},
#     {'original_char': 'M',
#      'position': 15,
#      'operations': ['hold_2'],
#      'hold_duration': 2,
#      'frame_start': 58,
#      'frame_end': 59,
#      'final_char': 'M'},
#     {'original_char': 'E',
#      'position': 16,
#      'operations': ['hold_2'],
#      'hold_duration': 2,
#      'frame_start': 60,
#      'frame_end': 61,
#      'final_char': 'E'}],
#    'stats': {'original_length': 17,
#     'noisy_length': 136,
#     'expansion_ratio': 8.0,
#     'operations_count': 28}},
#   {'id': 8,
#    'clean_text': 'I will call you',
#    'noisy_text': 'III[NO_SIGN] WWWIIIILLL[NO_SIGN]LLL[NO_SIGN][NO_SIGN] CC[NO_SIGN]A[NO_SIGN]LLL[NO_SIGN][NO_SIGN]LLLL[NO_SIGN] YYYOO[NO_SIGN]UUU',
#    'metadata': [{'original_char': 'I',
#      'position': 0,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 0,
#      'frame_end': 2,
#      'final_char': 'I'},
#     {'original_char': ' ',
#      'position': 1,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 4,
#      'frame_end': 4},
#     {'original_char': 'W',
#      'position': 2,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 5,
#      'frame_end': 7,
#      'final_char': 'W'},
#     {'original_char': 'I',
#      'position': 3,
#      'operations': ['hold_4', 'jitter_-1', 'jitter_-1'],
#      'hold_duration': 4,
#      'frame_start': 8,
#      'frame_end': 9,
#      'final_char': 'I'},
#     {'original_char': 'L',
#      'position': 4,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 10,
#      'frame_end': 12,
#      'final_char': 'L'},
#     {'original_char': 'L',
#      'position': 5,
#      'operations': ['hold_3', 'jitter_1', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 14,
#      'frame_end': 17,
#      'final_char': 'L'},
#     {'original_char': ' ',
#      'position': 6,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 20,
#      'frame_end': 20},
#     {'original_char': 'C',
#      'position': 7,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 21,
#      'frame_end': 22,
#      'final_char': 'C'},
#     {'original_char': 'A',
#      'position': 8,
#      'operations': ['hold_1', 'pause_1'],
#      'hold_duration': 1,
#      'frame_start': 24,
#      'frame_end': 24,
#      'final_char': 'A'},
#     {'original_char': 'L',
#      'position': 9,
#      'operations': ['hold_3', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 26,
#      'frame_end': 28,
#      'final_char': 'L'},
#     {'original_char': 'L',
#      'position': 10,
#      'operations': ['hold_4', 'jitter_1', 'jitter_1', 'pause_1'],
#      'hold_duration': 4,
#      'frame_start': 31,
#      'frame_end': 36,
#      'final_char': 'L'},
#     {'original_char': ' ',
#      'position': 11,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 38,
#      'frame_end': 38},
#     {'original_char': 'Y',
#      'position': 12,
#      'operations': ['hold_3', 'jitter_-1'],
#      'hold_duration': 3,
#      'frame_start': 39,
#      'frame_end': 40,
#      'final_char': 'Y'},
#     {'original_char': 'O',
#      'position': 13,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 41,
#      'frame_end': 42,
#      'final_char': 'O'},
#     {'original_char': 'U',
#      'position': 14,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 44,
#      'frame_end': 46,
#      'final_char': 'U'}],
#    'stats': {'original_length': 15,
#     'noisy_length': 127,
#     'expansion_ratio': 8.466666666666667,
#     'operations_count': 26}},
#   {'id': 9,
#    'clean_text': 'This is very easy',
#    'noisy_text': 'TTT[NO_SIGN]HH[NO_SIGN]IIISSS II[NO_SIGN]SSS[NO_SIGN] VVVV[NO_SIGN][NO_SIGN]EEEE[NO_SIGN][NO_SIGN]RRRR[NO_SIGN]YY[NO_SIGN] EE[NO_SIGN]AAAASSSS[NO_SIGN][NO_SIGN]YYYY',
#    'metadata': [{'original_char': 'T',
#      'position': 0,
#      'operations': ['hold_3', 'jitter_-1', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 0,
#      'frame_end': 1,
#      'final_char': 'T'},
#     {'original_char': 'H',
#      'position': 1,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 3,
#      'frame_end': 4,
#      'final_char': 'H'},
#     {'original_char': 'I',
#      'position': 2,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 6,
#      'frame_end': 8,
#      'final_char': 'I'},
#     {'original_char': 'S',
#      'position': 3,
#      'operations': ['hold_3', 'jitter_-1'],
#      'hold_duration': 3,
#      'frame_start': 9,
#      'frame_end': 10,
#      'final_char': 'S'},
#     {'original_char': ' ',
#      'position': 4,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 11,
#      'frame_end': 11},
#     {'original_char': 'I',
#      'position': 5,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 12,
#      'frame_end': 13,
#      'final_char': 'I'},
#     {'original_char': 'S',
#      'position': 6,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 15,
#      'frame_end': 17,
#      'final_char': 'S'},
#     {'original_char': ' ',
#      'position': 7,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 19,
#      'frame_end': 19},
#     {'original_char': 'V',
#      'position': 8,
#      'operations': ['hold_4', 'jitter_-1', 'jitter_1', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 20,
#      'frame_end': 23,
#      'final_char': 'V'},
#     {'original_char': 'E',
#      'position': 9,
#      'operations': ['hold_4', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 26,
#      'frame_end': 29,
#      'final_char': 'E'},
#     {'original_char': 'R',
#      'position': 10,
#      'operations': ['hold_4', 'pause_1'],
#      'hold_duration': 4,
#      'frame_start': 32,
#      'frame_end': 35,
#      'final_char': 'R'},
#     {'original_char': 'Y',
#      'position': 11,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 37,
#      'frame_end': 38,
#      'final_char': 'Y'},
#     {'original_char': ' ',
#      'position': 12,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 40,
#      'frame_end': 40},
#     {'original_char': 'E',
#      'position': 13,
#      'operations': ['hold_2', 'substituted_to_E', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 41,
#      'frame_end': 42,
#      'final_char': 'E'},
#     {'original_char': 'A',
#      'position': 14,
#      'operations': ['hold_4'],
#      'hold_duration': 4,
#      'frame_start': 44,
#      'frame_end': 47,
#      'final_char': 'A'},
#     {'original_char': 'S',
#      'position': 15,
#      'operations': ['hold_4', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 48,
#      'frame_end': 51,
#      'final_char': 'S'},
#     {'original_char': 'Y',
#      'position': 16,
#      'operations': ['hold_4'],
#      'hold_duration': 4,
#      'frame_start': 54,
#      'frame_end': 57,
#      'final_char': 'Y'}],
#    'stats': {'original_length': 17,
#     'noisy_length': 164,
#     'expansion_ratio': 9.647058823529411,
#     'operations_count': 29}},
#   {'id': 10,
#    'clean_text': 'Can you help me',
#    'noisy_text': 'CCCCCCC[NO_SIGN]NNNN[NO_SIGN][NO_SIGN] YYYYOOOO[NO_SIGN]UUU[NO_SIGN] NNNN[NO_SIGN]EE[NO_SIGN]LLL[NO_SIGN][NO_SIGN]PPP[NO_SIGN] MMM[NO_SIGN][NO_SIGN]EEEEE',
#    'metadata': [{'original_char': 'C',
#      'position': 0,
#      'operations': ['hold_7', 'jitter_1', 'jitter_1', 'pause_1'],
#      'hold_duration': 7,
#      'frame_start': 0,
#      'frame_end': 8,
#      'final_char': 'C'},
#     {'original_char': 'A',
#      'position': 1,
#      'operations': ['hold_4', 'deleted'],
#      'hold_duration': 4,
#      'final_char': '',
#      'frame_start': 10,
#      'frame_end': 10},
#     {'original_char': 'N',
#      'position': 2,
#      'operations': ['hold_4', 'jitter_1', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 10,
#      'frame_end': 14,
#      'final_char': 'N'},
#     {'original_char': ' ',
#      'position': 3,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 17,
#      'frame_end': 17},
#     {'original_char': 'Y',
#      'position': 4,
#      'operations': ['hold_4', 'jitter_-1'],
#      'hold_duration': 4,
#      'frame_start': 18,
#      'frame_end': 20,
#      'final_char': 'Y'},
#     {'original_char': 'O',
#      'position': 5,
#      'operations': ['hold_4', 'jitter_-1', 'jitter_1', 'pause_1'],
#      'hold_duration': 4,
#      'frame_start': 21,
#      'frame_end': 24,
#      'final_char': 'O'},
#     {'original_char': 'U',
#      'position': 6,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 26,
#      'frame_end': 28,
#      'final_char': 'U'},
#     {'original_char': ' ',
#      'position': 7,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 30,
#      'frame_end': 30},
#     {'original_char': 'H',
#      'position': 8,
#      'operations': ['hold_4', 'substituted_to_N', 'jitter_-1', 'pause_1'],
#      'hold_duration': 4,
#      'frame_start': 31,
#      'frame_end': 33,
#      'final_char': 'N'},
#     {'original_char': 'E',
#      'position': 9,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 35,
#      'frame_end': 36,
#      'final_char': 'E'},
#     {'original_char': 'L',
#      'position': 10,
#      'operations': ['hold_3', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 38,
#      'frame_end': 40,
#      'final_char': 'L'},
#     {'original_char': 'P',
#      'position': 11,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 43,
#      'frame_end': 45,
#      'final_char': 'P'},
#     {'original_char': ' ',
#      'position': 12,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 47,
#      'frame_end': 47},
#     {'original_char': 'M',
#      'position': 13,
#      'operations': ['hold_3', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 48,
#      'frame_end': 50,
#      'final_char': 'M'},
#     {'original_char': 'E',
#      'position': 14,
#      'operations': ['hold_5', 'jitter_1'],
#      'hold_duration': 5,
#      'frame_start': 53,
#      'frame_end': 58,
#      'final_char': 'E'}],
#    'stats': {'original_length': 15,
#     'noisy_length': 153,
#     'expansion_ratio': 10.2,
#     'operations_count': 31}},
#   {'id': 11,
#    'clean_text': 'I want some coffee',
#    'noisy_text': 'I WWWW[NO_SIGN][NO_SIGN]A[NO_SIGN]NNN[NO_SIGN][NO_SIGN]TTTT[NO_SIGN][NO_SIGN] SSSOO[NO_SIGN]MMEEEE CC[NO_SIGN]OOO[NO_SIGN]FFFFFEEEEEEEEE',
#    'metadata': [{'original_char': 'I',
#      'position': 0,
#      'operations': ['hold_1'],
#      'hold_duration': 1,
#      'frame_start': 0,
#      'frame_end': 0,
#      'final_char': 'I'},
#     {'original_char': ' ',
#      'position': 1,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 1,
#      'frame_end': 1},
#     {'original_char': 'W',
#      'position': 2,
#      'operations': ['hold_4', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 2,
#      'frame_end': 5,
#      'final_char': 'W'},
#     {'original_char': 'A',
#      'position': 3,
#      'operations': ['hold_1', 'pause_1'],
#      'hold_duration': 1,
#      'frame_start': 8,
#      'frame_end': 8,
#      'final_char': 'A'},
#     {'original_char': 'N',
#      'position': 4,
#      'operations': ['hold_3', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 10,
#      'frame_end': 12,
#      'final_char': 'N'},
#     {'original_char': 'T',
#      'position': 5,
#      'operations': ['hold_4', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 15,
#      'frame_end': 18,
#      'final_char': 'T'},
#     {'original_char': ' ',
#      'position': 6,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 21,
#      'frame_end': 21},
#     {'original_char': 'S',
#      'position': 7,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 22,
#      'frame_end': 24,
#      'final_char': 'S'},
#     {'original_char': 'O',
#      'position': 8,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 25,
#      'frame_end': 26,
#      'final_char': 'O'},
#     {'original_char': 'M',
#      'position': 9,
#      'operations': ['hold_2'],
#      'hold_duration': 2,
#      'frame_start': 28,
#      'frame_end': 29,
#      'final_char': 'M'},
#     {'original_char': 'E',
#      'position': 10,
#      'operations': ['hold_4'],
#      'hold_duration': 4,
#      'frame_start': 30,
#      'frame_end': 33,
#      'final_char': 'E'},
#     {'original_char': ' ',
#      'position': 11,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 34,
#      'frame_end': 34},
#     {'original_char': 'C',
#      'position': 12,
#      'operations': ['hold_2', 'jitter_-1', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 35,
#      'frame_end': 35,
#      'final_char': 'C'},
#     {'original_char': 'O',
#      'position': 13,
#      'operations': ['hold_3', 'jitter_-1', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 37,
#      'frame_end': 38,
#      'final_char': 'O'},
#     {'original_char': 'F',
#      'position': 14,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 40,
#      'frame_end': 42,
#      'final_char': 'F'},
#     {'original_char': 'F',
#      'position': 15,
#      'operations': ['hold_2', 'substituted_to_F'],
#      'hold_duration': 2,
#      'frame_start': 43,
#      'frame_end': 44,
#      'final_char': 'F'},
#     {'original_char': 'E',
#      'position': 16,
#      'operations': ['hold_5'],
#      'hold_duration': 5,
#      'frame_start': 45,
#      'frame_end': 49,
#      'final_char': 'E'},
#     {'original_char': 'E',
#      'position': 17,
#      'operations': ['hold_4', 'substituted_to_E'],
#      'hold_duration': 4,
#      'frame_start': 50,
#      'frame_end': 53,
#      'final_char': 'E'}],
#    'stats': {'original_length': 18,
#     'noisy_length': 136,
#     'expansion_ratio': 7.555555555555555,
#     'operations_count': 26}},
#   {'id': 12,
#    'clean_text': 'I am going home',
#    'noisy_text': 'I AAAMM GGGG[NO_SIGN]GGIII[NO_SIGN][NO_SIGN]NNNN[NO_SIGN][NO_SIGN]GGGG HH[NO_SIGN]OOO[NO_SIGN]WWW[NO_SIGN]EE',
#    'metadata': [{'original_char': 'I',
#      'position': 0,
#      'operations': ['hold_1'],
#      'hold_duration': 1,
#      'frame_start': 0,
#      'frame_end': 0,
#      'final_char': 'I'},
#     {'original_char': ' ',
#      'position': 1,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 1,
#      'frame_end': 1},
#     {'original_char': 'A',
#      'position': 2,
#      'operations': ['hold_3', 'jitter_1'],
#      'hold_duration': 3,
#      'frame_start': 2,
#      'frame_end': 5,
#      'final_char': 'A'},
#     {'original_char': 'M',
#      'position': 3,
#      'operations': ['hold_2'],
#      'hold_duration': 2,
#      'frame_start': 6,
#      'frame_end': 7,
#      'final_char': 'M'},
#     {'original_char': ' ',
#      'position': 4,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 8,
#      'frame_end': 8},
#     {'original_char': 'G',
#      'position': 5,
#      'operations': ['hold_4', 'jitter_1', 'jitter_-1', 'pause_1'],
#      'hold_duration': 4,
#      'frame_start': 9,
#      'frame_end': 12,
#      'final_char': 'G'},
#     {'original_char': 'O',
#      'position': 6,
#      'operations': ['hold_2', 'substituted_to_G'],
#      'hold_duration': 2,
#      'frame_start': 14,
#      'frame_end': 15,
#      'final_char': 'G'},
#     {'original_char': 'I',
#      'position': 7,
#      'operations': ['hold_3', 'substituted_to_I', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 16,
#      'frame_end': 18,
#      'final_char': 'I'},
#     {'original_char': 'N',
#      'position': 8,
#      'operations': ['hold_4', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 21,
#      'frame_end': 24,
#      'final_char': 'N'},
#     {'original_char': 'G',
#      'position': 9,
#      'operations': ['hold_4', 'jitter_1', 'jitter_-1'],
#      'hold_duration': 4,
#      'frame_start': 27,
#      'frame_end': 30,
#      'final_char': 'G'},
#     {'original_char': ' ',
#      'position': 10,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 31,
#      'frame_end': 31},
#     {'original_char': 'H',
#      'position': 11,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 32,
#      'frame_end': 33,
#      'final_char': 'H'},
#     {'original_char': 'O',
#      'position': 12,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 35,
#      'frame_end': 37,
#      'final_char': 'O'},
#     {'original_char': 'M',
#      'position': 13,
#      'operations': ['hold_3', 'substituted_to_W', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 39,
#      'frame_end': 41,
#      'final_char': 'W'},
#     {'original_char': 'E',
#      'position': 14,
#      'operations': ['hold_2'],
#      'hold_duration': 2,
#      'frame_start': 43,
#      'frame_end': 44,
#      'final_char': 'E'}],
#    'stats': {'original_length': 15,
#     'noisy_length': 108,
#     'expansion_ratio': 7.2,
#     'operations_count': 26}},
#   {'id': 13,
#    'clean_text': 'I love reading books',
#    'noisy_text': 'IIIII[NO_SIGN][NO_SIGN] LLL[NO_SIGN][NO_SIGN]OO[NO_SIGN][NO_SIGN]VVVV[NO_SIGN][NO_SIGN]EEEEE[NO_SIGN][NO_SIGN] RRRR[NO_SIGN]E[NO_SIGN]AAA[NO_SIGN]DDDD[NO_SIGN][NO_SIGN]II[NO_SIGN]NNN[NO_SIGN]GGGG[NO_SIGN][NO_SIGN] BBOOO[NO_SIGN][NO_SIGN]O[NO_SIGN][NO_SIGN]HH[NO_SIGN][NO_SIGN]SSS',
#    'metadata': [{'original_char': 'I',
#      'position': 0,
#      'operations': ['hold_5', 'jitter_-1', 'pause_2'],
#      'hold_duration': 5,
#      'frame_start': 0,
#      'frame_end': 3,
#      'final_char': 'I'},
#     {'original_char': ' ',
#      'position': 1,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 6,
#      'frame_end': 6},
#     {'original_char': 'L',
#      'position': 2,
#      'operations': ['hold_3', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 7,
#      'frame_end': 9,
#      'final_char': 'L'},
#     {'original_char': 'O',
#      'position': 3,
#      'operations': ['hold_2', 'jitter_1', 'pause_2'],
#      'hold_duration': 2,
#      'frame_start': 12,
#      'frame_end': 14,
#      'final_char': 'O'},
#     {'original_char': 'V',
#      'position': 4,
#      'operations': ['hold_4', 'jitter_1', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 17,
#      'frame_end': 21,
#      'final_char': 'V'},
#     {'original_char': 'E',
#      'position': 5,
#      'operations': ['hold_5', 'jitter_-1', 'pause_2'],
#      'hold_duration': 5,
#      'frame_start': 24,
#      'frame_end': 27,
#      'final_char': 'E'},
#     {'original_char': ' ',
#      'position': 6,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 30,
#      'frame_end': 30},
#     {'original_char': 'R',
#      'position': 7,
#      'operations': ['hold_4', 'pause_1'],
#      'hold_duration': 4,
#      'frame_start': 31,
#      'frame_end': 34,
#      'final_char': 'R'},
#     {'original_char': 'E',
#      'position': 8,
#      'operations': ['hold_1', 'substituted_to_E', 'pause_1'],
#      'hold_duration': 1,
#      'frame_start': 36,
#      'frame_end': 36,
#      'final_char': 'E'},
#     {'original_char': 'A',
#      'position': 9,
#      'operations': ['hold_3', 'jitter_-1', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 38,
#      'frame_end': 39,
#      'final_char': 'A'},
#     {'original_char': 'D',
#      'position': 10,
#      'operations': ['hold_4', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 41,
#      'frame_end': 44,
#      'final_char': 'D'},
#     {'original_char': 'I',
#      'position': 11,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 47,
#      'frame_end': 48,
#      'final_char': 'I'},
#     {'original_char': 'N',
#      'position': 12,
# ...
#      'frame_end': 8,
#      'final_char': 'H'},
#     {'original_char': 'E',
#      'position': 2,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 10,
#      'frame_end': 11,
#      'final_char': 'E'},
#     {'original_char': ' ',
#      'position': 3,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 13,
#      'frame_end': 13},
#     {'original_char': 'I',
#      'position': 4,
#      'operations': ['hold_4', 'substituted_to_L', 'jitter_1', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 14,
#      'frame_end': 18,
#      'final_char': 'L'},
#     {'original_char': 'S',
#      'position': 5,
#      'operations': ['hold_4', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 21,
#      'frame_end': 24,
#      'final_char': 'S'},
#     {'original_char': ' ',
#      'position': 6,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 27,
#      'frame_end': 27},
#     {'original_char': 'M',
#      'position': 7,
#      'operations': ['hold_1', 'pause_1'],
#      'hold_duration': 1,
#      'frame_start': 28,
#      'frame_end': 28,
#      'final_char': 'M'},
#     {'original_char': 'Y',
#      'position': 8,
#      'operations': ['hold_2', 'jitter_1', 'jitter_-1', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 30,
#      'frame_end': 31,
#      'final_char': 'Y'},
#     {'original_char': ' ',
#      'position': 9,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 33,
#      'frame_end': 33},
#     {'original_char': 'S',
#      'position': 10,
#      'operations': ['hold_1', 'pause_2'],
#      'hold_duration': 1,
#      'frame_start': 34,
#      'frame_end': 34,
#      'final_char': 'S'},
#     {'original_char': 'I',
#      'position': 11,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 37,
#      'frame_end': 39,
#      'final_char': 'I'},
#     {'original_char': 'S',
#      'position': 12,
#      'operations': ['hold_4', 'pause_1'],
#      'hold_duration': 4,
#      'frame_start': 40,
#      'frame_end': 43,
#      'final_char': 'S'},
#     {'original_char': 'T',
#      'position': 13,
#      'operations': ['hold_5', 'jitter_-1', 'jitter_1', 'jitter_-1', 'pause_1'],
#      'hold_duration': 5,
#      'frame_start': 45,
#      'frame_end': 48,
#      'final_char': 'T'},
#     {'original_char': 'E',
#      'position': 14,
#      'operations': ['hold_3', 'deleted'],
#      'hold_duration': 3,
#      'final_char': '',
#      'frame_start': 50,
#      'frame_end': 50},
#     {'original_char': 'R',
#      'position': 15,
#      'operations': ['hold_5', 'jitter_1', 'jitter_-1'],
#      'hold_duration': 5,
#      'frame_start': 50,
#      'frame_end': 54,
#      'final_char': 'R'}],
#    'stats': {'original_length': 16,
#     'noisy_length': 168,
#     'expansion_ratio': 10.5,
#     'operations_count': 34}},
#   {'id': 26,
#    'clean_text': 'Do you like it',
#    'noisy_text': 'DDO[NO_SIGN][NO_SIGN] YYY[NO_SIGN]OOOUUU[NO_SIGN] L[NO_SIGN][NO_SIGN]III[NO_SIGN]KK[NO_SIGN][NO_SIGN]EEEE[NO_SIGN][NO_SIGN] III[NO_SIGN][NO_SIGN]TT',
#    'metadata': [{'original_char': 'D',
#      'position': 0,
#      'operations': ['hold_2'],
#      'hold_duration': 2,
#      'frame_start': 0,
#      'frame_end': 1,
#      'final_char': 'D'},
#     {'original_char': 'O',
#      'position': 1,
#      'operations': ['hold_1', 'jitter_-1', 'pause_2'],
#      'hold_duration': 1,
#      'frame_start': 2,
#      'frame_end': 1,
#      'final_char': 'O'},
#     {'original_char': ' ',
#      'position': 2,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 4,
#      'frame_end': 4},
#     {'original_char': 'Y',
#      'position': 3,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 5,
#      'frame_end': 7,
#      'final_char': 'Y'},
#     {'original_char': 'O',
#      'position': 4,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 9,
#      'frame_end': 11,
#      'final_char': 'O'},
#     {'original_char': 'U',
#      'position': 5,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 12,
#      'frame_end': 14,
#      'final_char': 'U'},
#     {'original_char': ' ',
#      'position': 6,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 16,
#      'frame_end': 16},
#     {'original_char': 'L',
#      'position': 7,
#      'operations': ['hold_1', 'pause_2'],
#      'hold_duration': 1,
#      'frame_start': 17,
#      'frame_end': 17,
#      'final_char': 'L'},
#     {'original_char': 'I',
#      'position': 8,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 20,
#      'frame_end': 22,
#      'final_char': 'I'},
#     {'original_char': 'K',
#      'position': 9,
#      'operations': ['hold_2', 'pause_2'],
#      'hold_duration': 2,
#      'frame_start': 24,
#      'frame_end': 25,
#      'final_char': 'K'},
#     {'original_char': 'E',
#      'position': 10,
#      'operations': ['hold_4', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 28,
#      'frame_end': 31,
#      'final_char': 'E'},
#     {'original_char': ' ',
#      'position': 11,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 34,
#      'frame_end': 34},
#     {'original_char': 'I',
#      'position': 12,
#      'operations': ['hold_3', 'jitter_1', 'pause_2'],
#      'hold_duration': 3,
#      'frame_start': 35,
#      'frame_end': 38,
#      'final_char': 'I'},
#     {'original_char': 'T',
#      'position': 13,
#      'operations': ['hold_2'],
#      'hold_duration': 2,
#      'frame_start': 41,
#      'frame_end': 42,
#      'final_char': 'T'}],
#    'stats': {'original_length': 14,
#     'noisy_length': 147,
#     'expansion_ratio': 10.5,
#     'operations_count': 21}},
#   {'id': 27,
#    'clean_text': 'Do you know this',
#    'noisy_text': 'OOOO[NO_SIGN] YYYOOOO[NO_SIGN][NO_SIGN]UU[NO_SIGN] KKKKNN[NO_SIGN][NO_SIGN]GG[NO_SIGN][NO_SIGN]WWW FF[NO_SIGN]HH[NO_SIGN]IISSSSS',
#    'metadata': [{'original_char': 'D',
#      'position': 0,
#      'operations': ['hold_2', 'substituted_to_O', 'jitter_1'],
#      'hold_duration': 2,
#      'frame_start': 0,
#      'frame_end': 2,
#      'final_char': 'O'},
#     {'original_char': 'O',
#      'position': 1,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 3,
#      'frame_end': 4,
#      'final_char': 'O'},
#     {'original_char': ' ',
#      'position': 2,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 6,
#      'frame_end': 6},
#     {'original_char': 'Y',
#      'position': 3,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 7,
#      'frame_end': 9,
#      'final_char': 'Y'},
#     {'original_char': 'O',
#      'position': 4,
#      'operations': ['hold_4', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 10,
#      'frame_end': 13,
#      'final_char': 'O'},
#     {'original_char': 'U',
#      'position': 5,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 16,
#      'frame_end': 17,
#      'final_char': 'U'},
#     {'original_char': ' ',
#      'position': 6,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 19,
#      'frame_end': 19},
#     {'original_char': 'K',
#      'position': 7,
#      'operations': ['hold_4', 'jitter_-1'],
#      'hold_duration': 4,
#      'frame_start': 20,
#      'frame_end': 22,
#      'final_char': 'K'},
#     {'original_char': 'N',
#      'position': 8,
#      'operations': ['hold_2', 'pause_2'],
#      'hold_duration': 2,
#      'frame_start': 23,
#      'frame_end': 24,
#      'final_char': 'N'},
#     {'original_char': 'O',
#      'position': 9,
#      'operations': ['hold_2', 'substituted_to_G', 'pause_2'],
#      'hold_duration': 2,
#      'frame_start': 27,
#      'frame_end': 28,
#      'final_char': 'G'},
#     {'original_char': 'W',
#      'position': 10,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 31,
#      'frame_end': 33,
#      'final_char': 'W'},
#     {'original_char': ' ',
#      'position': 11,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 34,
#      'frame_end': 34},
#     {'original_char': 'T',
#      'position': 12,
#      'operations': ['hold_2', 'substituted_to_F', 'jitter_-1', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 35,
#      'frame_end': 35,
#      'final_char': 'F'},
#     {'original_char': 'H',
#      'position': 13,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 37,
#      'frame_end': 38,
#      'final_char': 'H'},
#     {'original_char': 'I',
#      'position': 14,
#      'operations': ['hold_2'],
#      'hold_duration': 2,
#      'frame_start': 40,
#      'frame_end': 41,
#      'final_char': 'I'},
#     {'original_char': 'S',
#      'position': 15,
#      'operations': ['hold_5', 'jitter_-1'],
#      'hold_duration': 5,
#      'frame_start': 42,
#      'frame_end': 45,
#      'final_char': 'S'}],
#    'stats': {'original_length': 16,
#     'noisy_length': 128,
#     'expansion_ratio': 8.0,
#     'operations_count': 27}},
#   {'id': 28,
#    'clean_text': 'We are learning Python',
#    'noisy_text': 'WWW[NO_SIGN]EE AAABBBEEE LLLLEEEEAARR[NO_SIGN][NO_SIGN]NNN[NO_SIGN]I[NO_SIGN][NO_SIGN]N[NO_SIGN]GGGG[NO_SIGN][NO_SIGN] PPPPPYYYTTTTHHH[NO_SIGN]OOOOOONNNN',
#    'metadata': [{'original_char': 'W',
#      'position': 0,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 0,
#      'frame_end': 2,
#      'final_char': 'W'},
#     {'original_char': 'E',
#      'position': 1,
#      'operations': ['hold_2'],
#      'hold_duration': 2,
#      'frame_start': 4,
#      'frame_end': 5,
#      'final_char': 'E'},
#     {'original_char': ' ',
#      'position': 2,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 6,
#      'frame_end': 6},
#     {'original_char': 'A',
#      'position': 3,
#      'operations': ['hold_3', 'jitter_-1'],
#      'hold_duration': 3,
#      'frame_start': 7,
#      'frame_end': 8,
#      'final_char': 'A'},
#     {'original_char': 'R',
#      'position': 4,
#      'operations': ['hold_3', 'substituted_to_B'],
#      'hold_duration': 3,
#      'frame_start': 9,
#      'frame_end': 11,
#      'final_char': 'B'},
#     {'original_char': 'E',
#      'position': 5,
#      'operations': ['hold_3', 'substituted_to_E'],
#      'hold_duration': 3,
#      'frame_start': 12,
#      'frame_end': 14,
#      'final_char': 'E'},
#     {'original_char': ' ',
#      'position': 6,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 15,
#      'frame_end': 15},
#     {'original_char': 'L',
#      'position': 7,
#      'operations': ['hold_4'],
#      'hold_duration': 4,
#      'frame_start': 16,
#      'frame_end': 19,
#      'final_char': 'L'},
#     {'original_char': 'E',
#      'position': 8,
#      'operations': ['hold_4', 'jitter_1', 'jitter_1'],
#      'hold_duration': 4,
#      'frame_start': 20,
#      'frame_end': 25,
#      'final_char': 'E'},
#     {'original_char': 'A',
#      'position': 9,
#      'operations': ['hold_2'],
#      'hold_duration': 2,
#      'frame_start': 26,
#      'frame_end': 27,
#      'final_char': 'A'},
#     {'original_char': 'R',
#      'position': 10,
#      'operations': ['hold_2', 'jitter_-1', 'pause_2'],
#      'hold_duration': 2,
#      'frame_start': 28,
#      'frame_end': 28,
#      'final_char': 'R'},
#     {'original_char': 'N',
#      'position': 11,
#      'operations': ['hold_3', 'substituted_to_N', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 31,
#      'frame_end': 33,
#      'final_char': 'N'},
#     {'original_char': 'I',
#      'position': 12,
#      'operations': ['hold_1', 'pause_2'],
#      'hold_duration': 1,
#      'frame_start': 35,
#      'frame_end': 35,
#      'final_char': 'I'},
#     {'original_char': 'N',
#      'position': 13,
#      'operations': ['hold_1', 'jitter_-1', 'pause_1'],
#      'hold_duration': 1,
#      'frame_start': 38,
#      'frame_end': 37,
#      'final_char': 'N'},
#     {'original_char': 'G',
#      'position': 14,
#      'operations': ['hold_4', 'pause_2'],
#      'hold_duration': 4,
#      'frame_start': 39,
#      'frame_end': 42,
#      'final_char': 'G'},
#     {'original_char': ' ',
#      'position': 15,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 45,
#      'frame_end': 45},
#     {'original_char': 'P',
#      'position': 16,
#      'operations': ['hold_5'],
#      'hold_duration': 5,
#      'frame_start': 46,
#      'frame_end': 50,
#      'final_char': 'P'},
#     {'original_char': 'Y',
#      'position': 17,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 51,
#      'frame_end': 53,
#      'final_char': 'Y'},
#     {'original_char': 'T',
#      'position': 18,
#      'operations': ['hold_4', 'jitter_1'],
#      'hold_duration': 4,
#      'frame_start': 54,
#      'frame_end': 58,
#      'final_char': 'T'},
#     {'original_char': 'H',
#      'position': 19,
#      'operations': ['hold_3', 'pause_1'],
#      'hold_duration': 3,
#      'frame_start': 59,
#      'frame_end': 61,
#      'final_char': 'H'},
#     {'original_char': 'O',
#      'position': 20,
#      'operations': ['hold_6', 'jitter_1'],
#      'hold_duration': 6,
#      'frame_start': 63,
#      'frame_end': 69,
#      'final_char': 'O'},
#     {'original_char': 'N',
#      'position': 21,
#      'operations': ['hold_4', 'jitter_-1'],
#      'hold_duration': 4,
#      'frame_start': 70,
#      'frame_end': 72,
#      'final_char': 'N'}],
#    'stats': {'original_length': 22,
#     'noisy_length': 153,
#     'expansion_ratio': 6.954545454545454,
#     'operations_count': 37}},
#   {'id': 29,
#    'clean_text': 'What time is it',
#    'noisy_text': 'WWWATTT TTII[NO_SIGN]MM[NO_SIGN]EE[NO_SIGN] IIIII[NO_SIGN][NO_SIGN]SSSS FFFF',
#    'metadata': [{'original_char': 'W',
#      'position': 0,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 0,
#      'frame_end': 2,
#      'final_char': 'W'},
#     {'original_char': 'H',
#      'position': 1,
#      'operations': ['hold_2', 'deleted'],
#      'hold_duration': 2,
#      'final_char': '',
#      'frame_start': 3,
#      'frame_end': 3},
#     {'original_char': 'A',
#      'position': 2,
#      'operations': ['hold_1'],
#      'hold_duration': 1,
#      'frame_start': 3,
#      'frame_end': 3,
#      'final_char': 'A'},
#     {'original_char': 'T',
#      'position': 3,
#      'operations': ['hold_3'],
#      'hold_duration': 3,
#      'frame_start': 4,
#      'frame_end': 6,
#      'final_char': 'T'},
#     {'original_char': ' ',
#      'position': 4,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 7,
#      'frame_end': 7},
#     {'original_char': 'T',
#      'position': 5,
#      'operations': ['hold_2'],
#      'hold_duration': 2,
#      'frame_start': 8,
#      'frame_end': 9,
#      'final_char': 'T'},
#     {'original_char': 'I',
#      'position': 6,
#      'operations': ['hold_2', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 10,
#      'frame_end': 11,
#      'final_char': 'I'},
#     {'original_char': 'M',
#      'position': 7,
#      'operations': ['hold_2', 'jitter_-1', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 13,
#      'frame_end': 13,
#      'final_char': 'M'},
#     {'original_char': 'E',
#      'position': 8,
#      'operations': ['hold_2', 'jitter_1', 'pause_1'],
#      'hold_duration': 2,
#      'frame_start': 15,
#      'frame_end': 17,
#      'final_char': 'E'},
#     {'original_char': ' ',
#      'position': 9,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 19,
#      'frame_end': 19},
#     {'original_char': 'I',
#      'position': 10,
#      'operations': ['hold_5', 'pause_2'],
#      'hold_duration': 5,
#      'frame_start': 20,
#      'frame_end': 24,
#      'final_char': 'I'},
#     {'original_char': 'S',
#      'position': 11,
#      'operations': ['hold_4'],
#      'hold_duration': 4,
#      'frame_start': 27,
#      'frame_end': 30,
#      'final_char': 'S'},
#     {'original_char': ' ',
#      'position': 12,
#      'operations': [],
#      'final_char': ' ',
#      'frame_start': 31,
#      'frame_end': 31},
#     {'original_char': 'I',
#      'position': 13,
#      'operations': ['hold_3', 'deleted'],
#      'hold_duration': 3,
#      'final_char': '',
#      'frame_start': 32,
#      'frame_end': 32},
#     {'original_char': 'T',
#      'position': 14,
#      'operations': ['hold_4', 'substituted_to_F', 'jitter_1'],
#      'hold_duration': 4,
#      'frame_start': 32,
#      'frame_end': 36,
#      'final_char': 'F'}],
#    'stats': {'original_length': 15,
#     'noisy_length': 76,
#     'expansion_ratio': 5.066666666666666,
#     'operations_count': 22}}]}

# %%
import os
os.makedirs("/content/drive/MyDrive/QHack", exist_ok = True)

# %%
## move asl_noisy_dataset.json from root to '/content/drive/MyDrive/QHack/asl_noisy_dataset.json'
import shutil

src = "asl_noisy_dataset.json"
dst = "/content/drive/MyDrive/QHack/asl_noisy_dataset.json"
shutil.move(src, dst)
# Out:
# '/content/drive/MyDrive/QHack/asl_noisy_dataset.json'
